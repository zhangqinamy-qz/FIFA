# %% [markdown]
# # World Cup Prediction - Data Exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
# Load your dataset here
# df = pd.read_csv('../data/raw/world_cup_matches.csv')
# df.head()
